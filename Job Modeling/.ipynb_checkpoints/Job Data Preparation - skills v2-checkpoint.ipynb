# %%
import json
import re
from typing import List
from tqdm import tqdm
from pydantic import BaseModel, Field
from langchain import PromptTemplate, LLMChain
from langchain.llms.ollama import Ollama
from langchain.output_parsers import PydanticOutputParser
from langchain.schema import OutputParserException

# Load jobs from JSON
with open("./data/shuffled_data.json", "r", encoding="utf-8") as file:
    jobs_list = json.load(file)

# Assign ID to each job if not already there
for index, job in enumerate(jobs_list, start=1):
    job["id"] = job.get("id", index)

# Define schemas
class Skill(BaseModel):
    skill: str
    influence: int = Field(..., ge=0, le=100)

class JobSkills(BaseModel):
    soft_skills: List[Skill]
    hard_skills: List[Skill]

output_parser = PydanticOutputParser(pydantic_object=JobSkills)
format_instructions = output_parser.get_format_instructions().replace("{", "{{").replace("}", "}}")


# Prompt template
prompt_template = f"""
You are given the job description text from a job posting. Your task is to extract the soft skills and hard skills required for the job mentioned in the job description.
Soft skills include communication, teamwork, adaptability, problem-solving, leadership, emotional intelligence, and time management.
Hard skills include (but are not limited to) the following:
- Programming and Software Development
- Data Analysis and Statistical Analysis
- Machine Learning and Artificial Intelligence
- SQL, Python, Java
- Cloud Computing (AWS, Azure, Google Cloud)
- Agile and Scrum Methodologies
- Programming and Software Development
- Data Analysis and Statistical Analysis
- Project Management
- Financial Analysis and Forecasting
- Technical Writing and Documentation
- Machine Learning and Artificial Intelligence
- Graphic Design and Visual Communication
- Digital Marketing and SEO/SEM
- Web Development
- Database Management and SQL
- Cybersecurity and Information Security
- IT Networking and Infrastructure Management
- Quality Assurance and Software Testing
- Computer-Aided Design (CAD) and 3D Modeling
- Engineering Design and Simulation
- Scientific Research and Laboratory Skills
- Legal Research and Compliance
- Social Media Management and Analytics
- Content Creation and Copywriting
- Multimedia Production and Video Editing
- Technical Support and Troubleshooting
- Operating Systems Administration
- DevOps and Continuous Integration/Deployment
- Agile and Scrum Methodologies
- Data Visualization
- Business Intelligence and Analytics
- Supply Chain Management and Logistics
- Sales and Negotiation Techniques
- Advanced Excel and Data Modeling
- Statistical Software Proficiency (R, SAS, SPSS)
- Cloud Computing (AWS, Azure, Google Cloud)
- Mobile Application Development
- Robotics and Automation Engineering
- Virtual Reality (VR) and Augmented Reality (AR) Development
- E-commerce Platform Management
- Digital Forensics and Incident Response
- Network Security Monitoring and Penetration Testing
- Biotechnology Techniques and Laboratory Procedures
- Geographic Information Systems (GIS) and Spatial Analysis
- Foreign Language Proficiency
- Medical Diagnosis and Patient Care
- Mechanical Engineering Design and Analysis
- Electronics Engineering and Circuit Design
- Management Consulting and Strategic Advisory

For each skill you extract, assign a percentage influence (0-100) based on how prominently it appears in the description.

Return ONLY the output in valid JSON format following this schema:
{format_instructions}

Job Description:
{{job_text}}
"""

template = PromptTemplate(input_variables=["job_text"], template=prompt_template)
llm = Ollama(model="llama3:8b", temperature=0, base_url="http://localhost:11434")
chain = LLMChain(llm=llm, prompt=template, output_parser=output_parser)

def clean_json_output(text: str) -> str:
    match = re.search(r'(\{.*\})', text, re.DOTALL)
    return match.group(1) if match else ""

def extract_skills(jobs_list: list, checkpoint_interval: int = 100) -> list:
    valid_jobs = []
    successful_parses = 0  # Counter for successfully parsed jobs
    for index, job in enumerate(tqdm(jobs_list, desc="Extracting skills"), start=1):
        job_desc = job.get("job_overview", "")
        if not job_desc:
            continue  # Skip jobs with no description

        try:
            result = chain.run(job_text=job_desc)
            skills = result.model_dump()

            # Check if the job has valid soft_skills and hard_skills
            if skills.get("soft_skills") and skills.get("hard_skills"):
                job["soft_skills"] = skills.get("soft_skills")
                job["hard_skills"] = skills.get("hard_skills")
                valid_jobs.append(job)
                successful_parses += 1  # Increment the successful parse counter
                print("Currently jobs added: ", successful_parses)
        except OutputParserException as e:
            raw_output = getattr(e, "llm_output", "")
            try:
                cleaned_output = clean_json_output(raw_output)
                skills = output_parser.parse(cleaned_output).model_dump()

                if skills.get("soft_skills") and skills.get("hard_skills"):
                    job["soft_skills"] = skills.get("soft_skills")
                    job["hard_skills"] = skills.get("hard_skills")
                    valid_jobs.append(job)
                    successful_parses += 1  # Increment the successful parse counter
                    print("Currently jobs added: ", successful_parses)
            except Exception as inner_exception:
                print(f"Error parsing job {job['id']} (skipped): {inner_exception}")
                continue  # Skip this job and proceed to the next one

        # Periodically save the current valid jobs list
        if index % checkpoint_interval == 0:
            checkpoint_file = f"./data/export/jobs_with_skills_new_checkpoint_{index}.json"
            with open(checkpoint_file, "w", encoding="utf-8") as f:
                json.dump(valid_jobs, f, indent=2)
            print(f"Checkpoint saved: {checkpoint_file}")

    print(f"Total jobs successfully parsed: {successful_parses}")  # Output total count
    return valid_jobs

# Process the job list
valid_jobs_list = extract_skills(jobs_list)

# Final output (optional save)
with open("./data/export/jobs_with_skills_final.json", "w", encoding="utf-8") as f:
    json.dump(valid_jobs_list, f, indent=2)

print(f"Total valid jobs with skills: {len(valid_jobs_list)}")
# Out:
# Extracting skills:   0%|                                                           | 1/9646 [00:10<26:50:03, 10.02s/it]
# Currently jobs added:  1
# {'url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=439&ao=1136043&s=21&guid=00000195c28f81808d9f6289ba6e6a37&src=GD_JOB_AD&t=ESR&vt=w&cs=1_9fb992c0&cb=1742867352623&jobListingId=1009678557408&jrtk=5-yul1-0-1in18v0fq21pl000-c25751a3dd40e010', 'company_url_overview': 'https://careers.synopsys.com/search-jobs', 'company_name': 'Synopsys', 'company_rating': 4, 'job_title': 'Director of Business Development, System Solutions', 'job_location': 'Sunnyvale, CA', 'job_overview': "We Are:\nAt Synopsys, we drive the innovations that shape the way we live and connect. Our technology is central to the Era of Pervasive Intelligence, from self-driving cars to learning machines. We lead in chip design, verification, and IP integration, empowering the creation of high-performance silicon chips and software content. Join us to transform the future through continuous technological innovation.\nYou Are:\nYou are a seasoned business development professional with a robust background in System Solutions, specifically focused on Digital Twins. You possess a blend of strategic vision and tactical expertise, with a proven track record of driving significant revenue growth and creating innovative solutions. Your established executive connections at target customers, particularly within Automotive and Aerospace sectors, make you a key player in defining strategic directions and growing market share. With a minimum of 25 years in the semiconductor and EDA industry and a bachelor's degree in electrical engineering or computer science, you bring a wealth of knowledge and experience to the table. You are entrepreneurial, creative, and have a history of successful deal closures and ecosystem relationship building. Your high energy, growth mindset, and excellent interpersonal skills make you a standout leader who can effectively manage projects and cross-functional teams.\nWhat You&rsquo;ll Be Doing:\nDefining and executing a multi-year business plan aimed at double digit revenue growth.\nDeveloping business development initiatives to enable both push and pull-through business strategies.\nCollaborating with the sales team on account strategies, business proposals, and closing deals.\nDriving executive relationship campaigns in partnership with the sales team.\nConnecting Synopsys executives with decision-makers to foster new business opportunities.\nEngaging with customers and leading researchers to stay up-to-date with industry technology trends.\nPartnering with the product management team to define new products and establish market requirements and product roadmaps.\nAdvising senior management on specialized business issues and competitive insights.\nThe Impact You Will Have:\nSignificantly growing Synopsys' revenue in the System Solutions space, particularly Digital Twins.\nEnhancing Synopsys' market share within the Automotive and Aerospace &amp; Government sectors.\nDriving innovation and creating new business opportunities through strategic executive connections.\nInfluencing product development and market strategies through partnership with the product management team.\nProviding valuable insights and competitive intelligence to senior management.\nContributing to Synopsys&rsquo; leadership in the Era of Pervasive Intelligence through continuous technological innovation.\nWhat You&rsquo;ll Need:\nCurrent experience in sales or business development at a software or design services company.\nStrong entrepreneurial spirit with proven deal creativity and closing experience.\nAbility to identify and translate customer demands into product and sales revenue.\nExperience in formulating and fostering ecosystem relationships.\nProven track record of collaborating with senior executives.\nTechnical knowledge of system tools and systems ecosystem.\nMinimum of 25+ years of experience in the semiconductor and EDA industry.\nBachelor&rsquo;s degree in electrical engineering or computer science.\nWho You Are:\nHigh energy, driven, and known for being resp ...
# Extracting skills:   0%|                                                           | 2/9646 [00:17<22:50:59,  8.53s/it]
# Error parsing job 2 (skipped): Invalid json output:
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Extracting skills:   0%|                                                           | 3/9646 [00:25<22:30:49,  8.40s/it]
# Currently jobs added:  2
# {'url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=1136043&s=58&guid=00000195ce5fa443ad5a96dc2cac2510&src=GD_JOB_AD&t=SR&vt=w&cs=1_e3584327&cb=1742924689318&jobListingId=1009676631196&jrtk=5-yul1-0-1in75v946kgpp800-e754fb96f7663822', 'company_url_overview': 'https://www.orlandohealth.com/careers', 'company_name': 'Orlando Health', 'company_rating': 4.2, 'job_title': 'Remote Contract Recruiter (Must Reside in Alabama)', 'job_location': 'Homewood, AL', 'job_overview': 'Position Summary:\n\nOur Alabama Region is seeking a talented contract recruiter who will act as a partner with hiring leaders to develop and implement the strategies necessary for attracting, accessing, sourcing, and creating a great experience for qualified applicants. This role involves collaborating with hiring leaders to understand staffing needs and develop effective recruitment strategies.\nSchedule: 8a-5p, M-F\n*This role is remote but requires attendance to local quarterly hiring events - must reside within a commutable distance*\n\nResponsibilities:\n\nEssential Functions\nConsults with department clients to define short term staffing needs.\nWorks closely with hiring manager to understand their business needs and keep updated on the active recruitment process.\nAbility to assess talent and ask questions that help draw out candidates&rsquo; skill sets\nEnsures a positive applicant and hiring manager experience throughout the hiring process which includes timely application follow up and interview status\nExecutes recruitment plans for assigned departments and or key roles by consulting with Senior recruiters or direct manager on sourcing strategies while taking into consideration other issues that may potentially impact the ability to recruit and or retain qualified staff including but not limited to, compensation and any other labor market issues.\nAttend career fairs and events on a regular basis to help build the brand and identify top talent\nWorks closely with state, Federal, collegiate, and professional entities to surface qualified candidates.\nRepresents Orlando Health brand, mission and values with pride, and emphasize features of employment with the organization and prepares candidates for a great interview experience. Ensures that applicants are treated professionally, has a comprehensive understanding of the job for which they are applying, and has a positive perception of Orlando Health.\nUnderstanding of department tools and processes.\nMaintains compliance with all Orlando Health policies and procedures.\nOther Related Functions\nTracks trends and developments in assigned areas\nParticipates in working groups, councils and committees\nParticipates in development of departmental goals and objectives\nContinually seeks to improve overall function of department\nDemonstrates the ability to work independently with little to no supervision\nMaintains confidentiality of all Orlando Health information\nAttends meetings/in-service and presents information in department and other meetings as requested\nAssumes responsibility for ongoing professional development and continued education\nHandles special projects as needed\n\nQualifications:\n\nEducation/Training.\nBachelors degree or equivalent experience (1 to 1 ratio) experience in sales, customer service, account management, recruiting, and or consulting\nExperience\n1 year of experience of progressively responsible human resources, sales, or customer service experience is required, to include no less than 6 months of sales or recruitment\n1 plus year sourcing on external platforms\nNo less than 1 year of experience working in a metric driven environment\nDemonstrated ability to be coached or mentored by others.\nExperience using TA/HR technology and/or HR systems.', 'company_headquarters': 'Orlando, FL', 'company_founded_year': '1918', 'company_industry': 'Health Care Services & Hospitals', 'company_revenue': '$10+ billion (USD)', 'company_size': '10000+ Employees', 'company_typ ...
# Extracting skills:   0%|                                                           | 4/9646 [00:34<22:41:14,  8.47s/it]
# Currently jobs added:  3
# {'url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=1328&ao=1136043&s=21&guid=00000195c297c3c999c91ce3cc371fed&src=GD_JOB_AD&t=ESR&vt=w&cs=1_6be9ddfe&cb=1742857933157&jobListingId=1009585985921&jrtk=5-yul1-0-1in19fh2221gd000-2e8aa10e7feeb7b7', 'company_url_overview': 'https://www.nordstrom.com/', 'company_name': 'Nordstrom Inc', 'company_rating': 3.5, 'job_title': 'Product Manager 2 - Retail Media, Advertising (Hybrid - Seattle)', 'job_location': 'Seattle, WA', 'job_overview': 'Job Description\nWe are looking for a Product Manager 2 who will play a crucial role in enhancing the customer experience through delivering exceptional advertising experiences on Nordstrom owned properties. These experiences will support our brands&rsquo; success and help our customers feel good and look their best.\nJob Summary:\nAs a member of the Nordstrom Media Network and Nordstrom Product Management teams, you will help drive forward our customer experience through increased relevance and enhanced customer journeys resulting in improved engagement and the growth of the media network. You will operate at the intersection of product management, ad sales, operations, merchandising, experience design, and engineering. Additionally, you will work across the broader Nordstrom digital product organization to build, launch and test ad products that complement the digital customer journey. You will use data-driven insights to build and implement a roadmap of ad experiences and capabilities. You will make product decisions that align with the guiding principles of the media network: enhance the customer experience, connect customers with brands, drive partner performance, and build products that are uniquely Nordstrom.\nA day in the life&hellip;\nProduct Strategy and Vision - Contribute to a product vision that is aligned with company goals and business priorities and evangelize with your squad and key stakeholders\nContinuous Discovery and Insights - Monitor key KPI performance, and keep current with customer and market research to provide insights for continuous improvements and feature opportunities\nPrioritization and Planning - Prioritize the product roadmap and feature backlog\nDefinition and Decomposition - Write user stories, acceptance criteria, and measurement plans\nCollaboration and Influence - Collaborate with the Media Network, Experience Design, Engineering, Analytics, and Marketing teams to create meaningful experiences for our customers\nDrive Impact - Embed with the Engineering squad to drive progress against deliverables through day-to-day management of backlog, agile ceremonies and launch planning\nWhat We Value:\nOur brand legacy of customer service\nCuriosity and learning\nCollaboration and diversity of thought\nEvidence-based outcomes\nSpeed to market and progress over perfection\nAccountability\nSimplicity\nExperimentation\nCustomer-centric mindset\nYou own this if you have&hellip;\n1-3 years of product management experience or equivalent with sponsored ad products or other retail advertising technology experience preferred\nBachelor&rsquo;s degree in Business, Math, Computer Science, or related discipline is preferred\nBasic technical background and understanding of software development principles, including Agile development and a/b testing methodologies\nAbility to build relationships cross-functionally with multiple teams from areas such as Analytics, Engineering, User Experience, and Marketing\nStrong verbal and written communication skills, including presenting to various levels within a matrixed organization\nProficient in data analysis and performance metrics, especially advertising metrics\nStrong critical thinking, analytical and problem-solving skills\nOutstanding organizational and time management skills\nWe&rsquo;ve got you covered&hellip;\nOur employees are our most important asset and that&rsquo;s reflected in our benefits. Nordstrom is proud to offer a variety of benefits to support employees and their fami ...
# Extracting skills:   0%|                                                           | 5/9646 [00:44<24:22:53,  9.10s/it]
# Error parsing job 5 (skipped): Invalid json output:
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Extracting skills:   0%|                                                           | 6/9646 [00:55<26:19:08,  9.83s/it]
# Error parsing job 6 (skipped): Invalid json output:
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Extracting skills:   0%|                                                           | 7/9646 [01:04<25:24:27,  9.49s/it]
# Currently jobs added:  4
# {'url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=734&ao=1136043&s=21&guid=00000195c293513c8f4668867f5171d7&src=GD_JOB_AD&t=ESR&vt=w&cs=1_6f741268&cb=1742796832440&jobListingId=1009611722700&jrtk=5-yul1-0-1in196kkqgc3n800-d72f710b79ab29f9', 'company_url_overview': 'https://www.gevernova.com/', 'company_name': 'GE Vernova', 'company_rating': 3.8, 'job_title': 'Wind Product Management Leadership Program', 'job_location': 'Schenectady, NY', 'job_overview': 'Job Description Summary\nWe are seeking a highly motivated and accomplished Wind Energy Professional with a strong engineering background and an MBA to join our 2-year leadership training program. This individual will have the unique opportunity to gain comprehensive business experience across various functions within our organization, including product management, strategy, commercial operations, supply chain, services, and engineering. The ideal candidate will be a strategic thinker with a proven track record in wind energy and a demonstrated ability to lead and manage complex projects.\nJob Description\nKey Responsibilities (depending on the rotation):\nProduct Management: Collaborate with cross-functional teams to develop and launch new wind energy products, ensuring alignment with market needs and company goals.\nStrategy Development: Participate in the development of strategic plans, including market analysis, competitive positioning, and business growth initiatives.\nCommercial Operations: Support the execution of commercial strategies, including sales and marketing initiatives, customer engagement, and revenue growth.\nSupply Chain Management: Work closely with supply chain teams to optimize procurement processes, manage inventory, and ensure timely delivery of components and materials.\nServices and Support: Contribute to the development and delivery of services and support programs for our customers, including maintenance, repair, and technical support.\nEngineering: Engage in engineering projects, including design, testing, and validation of wind energy systems, and contribute to continuous improvement initiatives.\nLeadership Development: Actively participate in leadership training and development activities, including workshops, mentoring, and coaching sessions.\nCross-functional Collaboration: Foster collaboration and communication across all departments to ensure seamless integration and alignment of business strategies.\nRequired Qualifications:\nBachelor&rsquo;s degree in engineering or science and an MBA.\nAt least 5 years of professional experience in the wind energy industry.\nDesired Characteristics:\nProven track record in leading and managing cross-functional projects\nStrong analytical and problem-solving skills.\nExcellent communication and interpersonal skills.\nProven ability to manage and mentor teams.\nFamiliarity with wind energy technology and industry standards.\nProficiency in project management methodologies and tools.\nExperience in product management, strategy development, and commercial operations.\nA background in supply chain management and services support.\nA history of successful project management and team leadership in the wind energy sector.\nExperience in international markets and cross-cultural team management.\nThe salary range for this position is $104,000.00 - $173,400.00 USD Annual.\nThe specific salary offered to a candidate may be influenced by a variety of factors including the candidate&rsquo;s experience, their education, and the work location. In addition, this role has variable compensation incentive of 10% . Available Health and Welfare benefits may include, Prescription drug, dental and vision coverage; saving account options (such as a Health Care Flexible Savings Account, Health Reimbursement Account, Limited Purpose Flexible Spending Account, and Dependent Care Flexible Spending Account); and an employee assistance program. Additional Benefits include a defined contribution 401(k) plan, employee life in ...
# Extracting skills:   0%|                                                           | 8/9646 [01:11<23:34:33,  8.81s/it]
# Currently jobs added:  5
# {'url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=102&ao=1136043&s=58&guid=00000195ce5f722d8c280e1039506421&src=GD_JOB_AD&t=SR&vt=w&cs=1_8fe516c6&cb=1742924669423&jobListingId=1009669343204&jrtk=5-yul1-0-1in75usk021g8000-02fa99d41ad5cba0', 'company_url_overview': 'https://www.ta-petro.com/', 'company_name': 'TravelCenters of America', 'company_rating': 3, 'job_title': 'Assistant Manager - Restaurant', 'job_location': 'McCalla, AL', 'job_overview': 'There&rsquo;s never been a better time to join TravelCenters of America! For more than 50 years, millions of professional truck drivers and motorists have called our travel centers home, depending on us daily for fuel, food, truck maintenance and essential services.\n\nDriven by a passionate team, TA is focused on growing its network of travel centers, implementing cutting edge technology and embarking on innovative alternative energy and sustainability initiatives.\n\nFrom our locations across the country, to our corporate headquarters in Westlake, Ohio, every team member is a stakeholder in TA&rsquo;s success. This environment offers endless career opportunities for individuals interested in sharing their ideas, growing with the company and shaping TA&rsquo;s future.\n\nJob Summary\n\nTravelCenters of America offers a convenient, one-stop shopping experience to our customers. Each location has a plethora of dining options which gives our guests the variety they look for. The Assistant Restaurant General Manager assists the General Manager with operations and marketing functions of the restaurant. Additional responsibilities include staffing, training and development, general supervision of the staff, and improving profitability. The Assistant General Manager ensures we are returning every traveler to the road better than they came!\n\nIn this role, you can expect to:\n\nBe a leader and inspire your team to meet and exceed company performance standards and improve the potential of the restaurant (i.e. fast and friendly customer service, good product knowledge, up-beat atmosphere, etc.)\nDevelop a trusting atmosphere that is conducive to receiving feedback from team members and guests; coach and performance manage staff according to company policy\nServe each customer courteously, quickly and efficiently with a sincere, positive, pleasant and enthusiastic attitude\nProvide great tasting / quality food, and a clean restaurant environment for all guests\nRecruit, hire, train and retain high-quality team members according to company guidelines and create a culture where team members feel respected and recognized for their achievements\nHelp achieve financial objectives through effective management of people, product, service and facility processes, including a focus on the revenue and profit components\nAdhere to safety standards and abide by standards of operation. Follow company guidelines on vendor relationships\nAssumes duties of any hourly associate position as necessary\n\nWhat we&rsquo;d like to see:\n\nA leader who sets the example when working alongside team members\nThe ability to lead, motivate, train and develop people to unleash the talent within each team member\nHigh School Diploma (or GED) required\nSupervisory experience in the full-service restaurant industry preferred\nExhibit good verbal and written communication skills\nAbility to work flexible hours including nights, weekends and some holidays\nProficient in Microsoft Office; Operational understanding of POS software\n\nWith us, you&rsquo;ll enjoy:\n\nCompetitive wages and annual bonus opportunity\nMedical, dental, vision and life insurance\n401(k) with a company match\nPaid vacation and holidays\nTuition reimbursement\nOn-site meal discounts\nA wide variety of discounts on technology, travel, food and fuel\nOpportunity for growth and advancement with company paid training\nRelocation Assistance (relocation not required)\n\nNot all benefit plans are available to all team members. For a more comprehensi ...
# Extracting skills:   0%|                                                           | 9/9646 [01:23<25:44:49,  9.62s/it]
# Currently jobs added:  6
# {'url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=220&ao=1136043&s=21&guid=00000195c29566469ba221013cb66f1c&src=GD_JOB_AD&t=ESR&vt=w&cs=1_4d67c1e1&cb=1742849055905&jobListingId=1009518729522&jrtk=5-yul1-0-1in19apndkuqi800-672de2c2370de64e', 'company_url_overview': 'https://careers.molinahealthcare.com/', 'company_name': 'Molina Healthcare', 'company_rating': 3.4, 'job_title': 'Principal Data Scientist - Generative AI, Machine Learning, Python, R - Remote', 'job_location': 'Arizona', 'job_overview': 'Job Description\n\nJob Summary\n\nResponsible for overseeing data science projects, managing and mentoring a team, and aligning data initiatives with business goals. Lead the development and implementation of data models, collaborate with cross-functional teams, and stay updated on industry trends. Ensure ethical data use and communicate complex technical concepts to non-technical stakeholders. Lead initiatives on model governance and model ops to align with regulatory and security requirements. This role requires technical expertise, strategic thinking, and leadership to drive data-driven decision-making within the organization and be the pioneer on generative AI healthcare solutions, aimed at revolutionizing healthcare operations as well as enhancing member experience.\n\nJob Duties\n\n\nResearch and Development: Stay current with the latest advancements in AI and machine learning and apply these insights to improve existing models and develop new methodologies.\nAI Model Deployment, Monitoring & Model Governance: Deploy AI models into production environments, monitor their performance, and adjust as necessary to maintain accuracy and effectiveness and meet all governance and regulatory requirements.\nInnovation Projects: Lead pilot projects to test and implement new AI technologies within the organization\nData Analysis and Interpretation: Extract meaningful insights from complex datasets, identify patterns, and interpret data to inform strategic decision-making.\nMachine Learning Model Development : Design, develop, and train machine learning models using a variety of algorithms and techniques, including supervised and unsupervised learning, deep learning, and reinforcement learning.\nAgentic Workflows Implementation: Develop and implement agentic workflows that utilize AI agents for autonomous task execution, enhancing operational efficiency and decision-making capabilities.\nRAG Pattern Utilization: Employ retrieval-augmented generation patterns to improve the performance of language models, ensuring they can access and utilize external knowledge effectively to enhance their outputs.\nModel Fine-Tuning : Fine-tune pre-trained models to adapt them to specific tasks or datasets, ensuring optimal performance and relevance in various applications.\nData Cleaning and Preprocessing: Prepare data for analysis by performing data cleaning, handling missing values, and removing outliers to ensure high-quality inputs for modeling.\nCollaboration: Work closely with cross-functional teams, including software engineers, product managers, and business analysts, to integrate AI solutions into existing systems and processes.\nDocumentation and Reporting: Create comprehensive documentation of models, methodologies, and results; communicate findings clearly to non-technical stakeholders.\nMentors, coaches, and provides guidance to newer data scientists.\nPartner closely with business and other technology teams to build ML models which helps in improving Star ratings, reduce care gap and other business objectives.\nPresent complex analytical information to all level of audiences in a clear and concise manner Collaborate with analytics team, assigning and managing delivery of analytical projects as appropriate\nPerform other duties as business requirements change, looking out for data solutions and technology enabled solution opportunities and make referrals to the appropriate team members in building out payment integrity solutions.\ ...
# Extracting skills:   0%|                                                          | 10/9646 [01:33<26:13:34,  9.80s/it]
# Currently jobs added:  7
# {'url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=117&ao=1136043&s=58&guid=00000192bbdf8258b5b51338873116a8&src=GD_JOB_AD&t=SR&vt=w&cs=1_5dba99cc&cb=1730820063758&jobListingId=1009496036729&jrtk=5-yul1-0-1iattv0l4gqr2800-7a1e15024913671c', 'company_url_overview': 'https://appliedmaterials.com/', 'company_name': 'Applied Materials', 'company_rating': 4, 'job_title': 'Software Engineer - Doctorate Degree', 'job_location': 'Santa Clara, CA', 'job_overview': 'Who We Are\nApplied Materials is the global leader in materials engineering solutions used to produce virtually every new chip and advanced display in the world. We design, build and service cutting-edge equipment that helps our customers manufacture display and semiconductor chips &ndash; the brains of devices we use every day. As the foundation of the global electronics industry, Applied enables the exciting technologies that literally connect our world &ndash; like AI and IoT. If you want to work beyond the cutting-edge, continuously pushing the boundaries of science and engineering to make possible the next generations of technology, join us to Make Possible&reg; a Better Future.\nAt Applied, we prioritize your well-being and encourage you to bring your best self to work. Your happiness, health, and resiliency are at the core of our benefits and wellness programs. Our robust total rewards package makes it easier to take care of your whole self and your whole family. We&rsquo;re committed to providing programs and support that encourage personal and professional growth and care for you at work, at home, or wherever you may go. Learn more about our Benefits.\nWhat You&rsquo;ll Do\nAs a Software Engineer at Applied Materials, you&rsquo;ll dive deep into ground-breaking technologies&mdash;like machine learning and AI&mdash;pushing the boundaries to craft novel software solutions that solve our customers&rsquo; high-value problems. You&rsquo;ll work on interesting and challenging projects, contributing your expertise in intricate systems, deciphering code, and anticipating software behaviors to ensure Applied remains the leader in the semiconductor and display sectors.\nWe empower our software engineers to experiment and push the boundaries of what is possible&mdash;while learning every day in a supportive leading global company. To learn about engineering at Applied and our advanced technology and research, visit our Engineering Careers page.\nRole Responsibilities:\nDevelop code for software projects, designing and implementing bug fixes, and designing\ngeneral software projects\nPerform software tests on code and enhancements\nDevelop software documentation\nDevelop and enhance software tools used for communicating to external components via Ethernet-based protocols\nAnalyze and troubleshoot various Ethernet protocol interfaces\nInterface with internal customers for requirements analysis\nPerform basic engineering analysis under general supervision\nTroubleshoot a variety of moderately complex software and communication protocol problems\nMinimum Qualifications:\nGraduating with a Master&rsquo;s of PhD degree in Computer Science, Software Engineering, Computer Engineering, or a related field\nGood academic standing with a GPA of 3.0 or above on a 4.0 scale\nExperience with at least one of the following programming languages: C/C++/C# for either application or embedded development\nProgramming experience in any of the following areas a plus: DBMS (SQL/no-SQL), Multithreading, Performance Profiling, TCP Sockets, REST/gRPC, Generative AI\nPreferred Qualifications:\nScripting knowledge with Python\nPrevious internship or related field experience\nDemonstrated leadership experience\nAble to solve complex problems and take a new perspective on existing solutions\nAbility to exercise judgment based on the analysis of multiple sources of information\nExplains difficult or sensitive information; works to build consensus\nFlexible and adaptable mindset who thrives in a re ...
# Extracting skills:   0%|                                                          | 11/9646 [01:42<25:11:05,  9.41s/it]
# Error parsing job 11 (skipped): Invalid json output:
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Extracting skills:   0%|                                                          | 12/9646 [01:48<22:28:57,  8.40s/it]
# Error parsing job 12 (skipped): Invalid json output:
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Extracting skills:   0%|                                                          | 13/9646 [01:54<20:49:19,  7.78s/it]
# Error parsing job 13 (skipped): Invalid json output:
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Extracting skills:   0%|                                                          | 14/9646 [02:04<22:57:00,  8.58s/it]
# Error parsing job 14 (skipped): Invalid json output:
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Extracting skills:   0%|                                                          | 15/9646 [02:17<25:50:35,  9.66s/it]
# Currently jobs added:  8
# {'url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=122&ao=1136043&s=21&guid=00000195c287b3b29a2ac0241fd60a5a&src=GD_JOB_AD&t=ESR&vt=w&cs=1_becc0d9c&cb=1742854646563&jobListingId=1009617559452&jrtk=5-yul1-0-1in18fd1pgcua801-f7616b0d4ad96b38', 'company_url_overview': 'https://www.whirlpoolcorp.com/', 'company_name': 'Whirlpool', 'company_rating': 3.7, 'job_title': 'Sr Embedded Software Engineer', 'job_location': 'Benton Harbor, MI', 'job_overview': "Requisition ID: 66372\nABOUT WHIRLPOOL CORPORATION\nWhirlpool Corporation (NYSE: WHR) is a leading kitchen and laundry appliance company, in constant pursuit of improving life at home and inspiring generations with our brands. The company is driving meaningful innovation to meet the evolving needs of consumers through its iconic brand portfolio, including Whirlpool, KitchenAid, JennAir, Maytag, Amana, Brastemp, Consul, and InSinkErator. In 2023, the company reported approximately $19 billion in annual sales, 59,000 employees, and 55 manufacturing and technology research centers. Additional information about the company can be found at WhirlpoolCorp.com.\nThe team you will be a part of\nThe Software Engineering team designs, develops or coordinates development/troubleshooting or debugging of moderately complex software programs for enhancements and new products. Performs high-level design/modeling to convert stakeholder needs into software solutions. Develops software and tools in support of design, infrastructure and technology platforms. Determines hardware compatibility and/or influences hardware design. Develops the architectural guidelines, specifications, and technical standards and communicates to stakeholders.\nThis role in summary\n\nWe are looking for a talented Embedded SW Software developer - Embedded SW developer to be part of an advanced software development. team within the Global Electronics organization at Whirlpool. You will be part of the global team that is responsible for developing software for all Whirlpool products.\nThe Senior Software developer will play a key role in development of GUI applications which includes Android, Embedded GUI; for Whirlpools range of smart appliances. The candidate developer will lead integration of SDK and consumer UX/UI requirements to deliver rich consumer experience for high end appliances appliance segments, value added services using Whirlpool&rsquo;s IoT platform.\nYour responsibilities will include\n\nContribute to the overall implementation of smart products working in scrum agile team\nFollow and implement sound software development practices\nEnsures adherence to coding standards and procedures.\nProvide creative solutions to complex problems, mentors team / peers in complex problem solvings\nParticipate in functional, technical, and code review\nEnsures Test coverage though automated unit tests, and lead software quality metrics\nApply dev skills and state of the art industry solutions for embedded software and bring the best of these solutions to Whirlpool products.\nDevelop and implement sound software development practices including continuous integration, nighty build &amp; regression testing, test driven design\nMentor, Lead and Assist other engineers through governance on code quality, metrics, and help them to resolve blockers\nWork in Agile and Waterfall environments.\nIntegrating Software into Home Appliances\nCreates value through advance development, innovation (Patents / Trade secret / Technical breakthrough)\nProvide technical leadership and direction for team members\nMinimum requirements\n\nExcellent understanding of computer science fundamentals including data structures, algorithms, object-oriented design, operating systems, etc.\nExperience with a variety of languages and paradigms, including: C/C++, JavaScript, Java and scripting languages\nKnowledge of oriented object programming\n3+ years of experience with multi-process, multi-tasking or multi-threaded based Operating Systems (RTOS or Lin ...
# Extracting skills:   0%|                                                          | 16/9646 [02:27<26:36:07,  9.94s/it]
# Currently jobs added:  9
# {'url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=935&ao=1136043&s=21&guid=00000195c291c7d88582d21a7dcad432&src=GD_JOB_AD&t=ESR&vt=w&cs=1_e08611bd&cb=1742858544039&jobListingId=1009676388206&jrtk=5-yul1-0-1in193i41jn1e800-642eb9a88fea89be', 'company_url_overview': 'https://jobs.johnsoncontrols.com/', 'company_name': 'Johnson Controls', 'company_rating': 3.6, 'job_title': 'HVAC Controls Engineer (Job number: 1208)', 'job_location': 'Arlington, VA', 'job_overview': "Job Description\nWe are seeking a Controls Engineer to join our federal team supporting the Fort McNair and Fort Myer military bases in Arlington, VA. Our team here is responsible for the Industrial Control Systems across the bases, primarily working with HVAC mechanical, HVAC controls (BAS/DDC), utilities, metering, lighting, and other building technologies.\nAt Johnson Controls, we support our nation&rsquo;s most critical facilities, the people who occupy them, and the missions they enable. Johnson Controls Federal Systems (JCFS) is a specialized team serving as a trusted partner to the federal government. We help modernize U.S. military installations, Department of Defense sites, and other federal agency facilities to be smarter, more resilient, efficient, sustainable, and secure.\n\nLocation: Will primarily support the Fort McNair and Fort Myer military bases in Arlington (Military experience is not required.)\nShift: Day Shift, Monday-Friday. Team primarily works 6:30am - 3:00pm.\nBenefits: Eligible for benefits on first day of employment.\nPaid Time Off: 3 weeks of paid vacation, 5 sick days, 3 floating holidays, and 10 standard holidays per calendar year (6.5 weeks in total)\nAs a Controls Engineer with our team you will:\nCreate sequence of operations and control drawings using tools like Visio.\nCreate, test, and download control systems for air handlers, central plants, or VAV boxes\nDiagnose and correct programming issues in the field.\nSupport technicians by ensuring the quality, timeliness and efficiency of designs while commissioning new building control systems.\nProvides support to the mechanical staff to assist with troubleshooting issues.\nCompiles job documentation, such as certificate of completion, customer training forms, training certificates and punch\nCoordinate drawings and equipment schedules to include in detailed information and submittal packages that communicate design and operation to customers, consultants, field installation team and subcontractors\nValidate complete system functionality\nProvide site-specific training for owner/operator on the total building control system\nRequired Qualifications:\n3+ years of experience programming, commissioning, and troubleshooting Direct Digital Control (DDC) systems. Experience with creating programs and troubleshooting in one or more of the following brands of HVAC Controls products is highly desired: Johnson Controls Metasys, Tridium Niagara, Siemens Apogee, Distech, Carrier, ALC, and/or Andover.\nExperience with BAS communication protocols should include one of the following: BACnet MSTP, BACnet IP, N2, P1, Modbus, and/or LON.\nDemonstrated knowledge and experience creating Sequence of Operations for control systems\nThe ability to obtain and maintain required government security clearance to perform work at this site required. (This involves a background/character, criminal history, employment, and credit check.)\nPreferred Qualifications:\nDemonstrated experience programming with Tridium Niagara or Metasys Direct Digital Control (DDC) system\nExperience working with SMP, SCT, and/or CCT\nExperience creating SCT databases, custom programs, schedules, trends, alarms, and programming modules\nDemonstrated knowledge of AutoCad or Visio\nPreferred Education:\nBachelor's Degree in Engineering, Computer Science or a related field, a Vocational School four year program certificate, an Associate&rsquo;s Degree in Electronics, Mechanical Systems, Computer Technology, HVAC, or a similar  ...
# Extracting skills:   0%|                                                          | 17/9646 [02:36<25:56:15,  9.70s/it]
# Currently jobs added:  10
# {'url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=229&ao=1136043&s=21&guid=00000195c28a0b759b31931a83703a33&src=GD_JOB_AD&t=ESR&vt=w&cs=1_a76e071d&cb=1742866974297&jobListingId=1009630620354&jrtk=5-yul1-0-1in18k302jcme800-5dc873f38e4326f8', 'company_url_overview': 'https://www.alcon.com/careers', 'company_name': 'Alcon', 'company_rating': 3.7, 'job_title': 'Director, Clinical R&D', 'job_location': 'Fort Worth, TX', 'job_overview': 'At Alcon, we are driven by the meaningful work we do to help people see brilliantly. We innovate boldly, champion progress, and act with speed as the global leader in eye care. Here, you&rsquo;ll be recognized for your commitment and contributions and see your career like never before. Together, we go above and beyond to make an impact in the lives of our patients and customers.\nWe foster an inclusive culture and are looking for diverse, talented people to join Alcon. As a Director, Clinical R&amp;D supporting the U.S. R&amp;D Clinical Team, in Fort Worth, TX, Johns Creek, GA, or Lake Forest California, typical day will include:\nAct as the primary vision science/scientific expert to the R&amp;D project teams and, pipeline teams across the surgical and vision care franchise.\nAct as the scientific expert in vision science, ophthalmology, and optometry, providing insights into emerging trends, unmet needs, and potential therapeutic advancements.\nConduct in-depth analysis of scientific and clinical data, identifying key findings and making data-driven recommendations to leadership.\nProvide clinical expertise in evaluating new therapeutic modalities, devices, and diagnostic innovations, and driving novel clinical endpoint development in vision science specifically in the areas of presbyopia, intraocular lenses, and contact lenses.\nDrive the execution of multiple high-priority clinical R&amp;D initiatives, ensuring timely progress and alignment with corporate strategy.\nLead the clinical assessment and evaluation of external technologies, assets, and partnerships in ophthalmic innovation, as assigned.\nLead with a sense of urgency, ensuring that projects remain on track and key milestones are met.\nMentor and guide internal teams, fostering a high-performance culture within Clinical R&amp;D.\nRole may also involve managing a small group (2-3) of vision science/clinical project leads.\nRepresent the company at scientific meetings, industry conferences, and advisory boards.\nMay be responsible for post marketing studies.\nWHAT YOU&rsquo;LL BRING TO ALCON:\nBachelor&rsquo;s Degree or Equivalent years of directly related experience (or high school +18 yrs; Assoc.+14 yrs; M.S.+7 yrs; PhD+6 yrs)\nThe ability to fluently read, write, understand and communicate in English\n10 Years of Relevant Experience ork hours:\nTravel: 20%\nRelocation: Yes\nSponsorship Assistance: Yes\nPreferred:\nAdvanced degree (MD, OD, PhD, or equivalent) in ophthalmology, optometry, vision science, or\na related field.\nExtensive experience in the ophthalmic industry, with a strong background in\nClinical research and development.\nExpertise in analyzing clinical data, identifying key trends, and providing actionable insights.\nStrong leadership skills with experience managing multiple projects in a fast-paced environment.\nExperience in multiple therapeutic areas/portfolio(s) within ophthalmology/optometry is a plus.\nDemonstrated ability to work cross-functionally with regulatory, R&amp;D, and leading teams in a matrix environment\nExceptional communication and presentation skills, with the ability to influence senior leadership and external stakeholders\nHOW YOU CAN THRIVE:\nCollaborate with teammates to share standard processes and findings as work evolves\nSee your career like never before with focused growth and development opportunities\nJoin Alcon&rsquo;s mission to provide outstanding, innovative products and solutions to improve sight, improve lives, and grow your career!\nAlcon provides robust benefits packag ...
# Extracting skills:   0%|                                                          | 18/9646 [02:47<26:27:51,  9.90s/it]
# Error parsing job 18 (skipped): Invalid json output:
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Extracting skills:   0%|                                                          | 19/9646 [02:53<23:29:16,  8.78s/it]
# Error parsing job 19 (skipped): Invalid json output:
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Extracting skills:   0%|                                                          | 20/9646 [02:59<21:21:28,  7.99s/it]
# Error parsing job 20 (skipped): Invalid json output:
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Extracting skills:   0%|▏                                                         | 21/9646 [03:05<19:53:48,  7.44s/it]
# Error parsing job 21 (skipped): Invalid json output:
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Extracting skills:   0%|▏                                                         | 22/9646 [03:16<22:26:58,  8.40s/it]
# Error parsing job 22 (skipped): Invalid json output:
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Extracting skills:   0%|▏                                                         | 24/9646 [03:32<22:35:38,  8.45s/it]
# Currently jobs added:  11
# ...
# Extracting skills:   0%|▏                                                         | 40/9646 [05:42<24:20:22,  9.12s/it]
# Error parsing job 40 (skipped): Failed to parse JobSkills from completion {"soft_skills": [{"skill": "Communication", "level": "Excellent"}, {"skill": "Problem-solving", "level": "Highly skilled"}, {"skill": "Collaboration", "level": "Strong foundation in SASE required"}, {"skill": "Influencing", "level": "Proven experience influencing sales teams and managing projects"}], "hard_skills": [{"skill": "GTM strategy", "level": "8-12+ years of combined experience in GTM strategy, sales strategy, sales consulting, pre-sales consulting"}, {"skill": "SASE/SD-WAN market product, strategy and/or GTM functions", "level": "3+ years preferred (strong foundational technical expertise in SASE required)"}, {"skill": "SaaS, B2B technology and/or cybersecurity", "level": "3+ years experience preferred"}]}. Got: 7 validation errors for JobSkills
# soft_skills.0.influence
#   Field required [type=missing, input_value={'skill': 'Communication', 'level': 'Excellent'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# soft_skills.1.influence
#   Field required [type=missing, input_value={'skill': 'Problem-solvin...evel': 'Highly skilled'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# soft_skills.2.influence
#   Field required [type=missing, input_value={'skill': 'Collaboration'...ation in SASE required'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# soft_skills.3.influence
#   Field required [type=missing, input_value={'skill': 'Influencing', ... and managing projects'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# hard_skills.0.influence
#   Field required [type=missing, input_value={'skill': 'GTM strategy',..., pre-sales consulting'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# hard_skills.1.influence
#   Field required [type=missing, input_value={'skill': 'SASE/SD-WAN ma...tise in SASE required)'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# hard_skills.2.influence
#   Field required [type=missing, input_value={'skill': 'SaaS, B2B tech...s experience preferred'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Extracting skills:   0%|▏                                                         | 40/9646 [05:47<23:11:12,  8.69s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 153
#     150     return valid_jobs
#     152 # Process the job list
# --> 153 valid_jobs_list = extract_skills(jobs_list)
#     155 # Final output (optional save)
#     156 with open("./data/export/jobs_with_skills_final.json", "w", encoding="utf-8") as f:
#
# Cell In[4], line 114, in extract_skills(jobs_list, checkpoint_interval)
#     111     continue  # Skip jobs with no description
#     113 try:
# --> 114     result = chain.run(job_text=job_desc)
#     115     skills = result.model_dump()
#     117     # Check if the job has valid soft_skills and hard_skills
#
# File C:\ProgramData\anaconda3\envs\torch_env\lib\site-packages\langchain_core\_api\deprecation.py:181, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     179     warned = True
#     180     emit_warning()
# --> 181 return wrapped(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\envs\torch_env\lib\site-packages\langchain\chains\base.py:611, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     606     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     607         _output_key
#     608     ]
#     610 if kwargs and not args:
# --> 611     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     612         _output_key
#     613     ]
#     615 if not kwargs and not args:
#     616     raise ValueError(
#     617         "`run` supported with either positional arguments or keyword arguments,"
#     618         " but none were provided."
#     619     )
#
# File C:\ProgramData\anaconda3\envs\torch_env\lib\site-packages\langchain_core\_api\deprecation.py:181, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     179     warned = True
#     180     emit_warning()
# --> 181 return wrapped(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\envs\torch_env\lib\site-packages\langchain\chains\base.py:389, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     357 """Execute the chain.
#     358
#     359 Args:
#    (...)
#     380         `Chain.output_keys`.
#     381 """
#     382 config = {
#     383     "callbacks": callbacks,
#     384     "tags": tags,
#     385     "metadata": metadata,
#     386     "run_name": run_name,
#     387 }
# --> 389 return self.invoke(
#     390     inputs,
#     391     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     392     return_only_outputs=return_only_outputs,
#     393     include_run_info=include_run_info,
#     394 )
#
# File C:\ProgramData\anaconda3\envs\torch_env\lib\site-packages\langchain\chains\base.py:170, in Chain.invoke(self, input, config, **kwargs)
#     168 except BaseException as e:
#     169     run_manager.on_chain_error(e)
# --> 170     raise e
#     171 run_manager.on_chain_end(outputs)
#     173 if include_run_info:
#
# File C:\ProgramData\anaconda3\envs\torch_env\lib\site-packages\langchain\chains\base.py:160, in Chain.invoke(self, input, config, **kwargs)
#     157 try:
#     158     self._validate_inputs(inputs)
#     159     outputs = (
# --> 160         self._call(inputs, run_manager=run_manager)
#     161         if new_arg_supported
#     162         else self._call(inputs)
#     163     )
#     165     final_outputs: Dict[str, Any] = self.prep_outputs(
#     166         inputs, outputs, return_only_outputs
#     167     )
#     168 except BaseException as e:
#
# File C:\ProgramData\anaconda3\envs\torch_env\lib\site-packages\langchain\chains\llm.py:126, in LLMChain._call(self, inputs, run_manager)
#     121 def _call(
#     122     self,
#     123     inputs: Dict[str, Any],
#     124     run_manager: Optional[CallbackManagerForChainRun] = None,
#     125 ) -> Dict[str, str]:
# --> 126     response = self.generate([inputs], run_manager=run_manager)
#     127     return self.create_outputs(response)[0]
#
# File C:\ProgramData\anaconda3\envs\torch_env\lib\site-packages\langchain\chains\llm.py:138, in LLMChain.generate(self, input_list, run_manager)
#     136 callbacks = run_manager.get_child() if run_manager else None
#     137 if isinstance(self.llm, BaseLanguageModel):
# --> 138     return self.llm.generate_prompt(
#     139         prompts,
#     140         stop,
#     141         callbacks=callbacks,
#     142         **self.llm_kwargs,
#     143     )
#     144 else:
#     145     results = self.llm.bind(stop=stop, **self.llm_kwargs).batch(
#     146         cast(List, prompts), {"callbacks": callbacks}
#     147     )
#
# File C:\ProgramData\anaconda3\envs\torch_env\lib\site-packages\langchain_core\language_models\llms.py:760, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     752 def generate_prompt(
#     753     self,
#     754     prompts: list[PromptValue],
#    (...)
#     757     **kwargs: Any,
#     758 ) -> LLMResult:
#     759     prompt_strings = [p.to_string() for p in prompts]
# --> 760     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File C:\ProgramData\anaconda3\envs\torch_env\lib\site-packages\langchain_core\language_models\llms.py:963, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     948 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     949     run_managers = [
#     950         callback_manager.on_llm_start(
#     951             self._serialized,
#    (...)
#     961         )
#     962     ]
# --> 963     output = self._generate_helper(
#     964         prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     965     )
#     966     return output
#     967 if len(missing_prompts) > 0:
#
# File C:\ProgramData\anaconda3\envs\torch_env\lib\site-packages\langchain_core\language_models\llms.py:784, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     774 def _generate_helper(
#     775     self,
#     776     prompts: list[str],
#    (...)
#     780     **kwargs: Any,
#     781 ) -> LLMResult:
#     782     try:
#     783         output = (
# --> 784             self._generate(
#     785                 prompts,
#     786                 stop=stop,
#     787                 # TODO: support multiple run managers
#     788                 run_manager=run_managers[0] if run_managers else None,
#     789                 **kwargs,
#     790             )
#     791             if new_arg_supported
#     792             else self._generate(prompts, stop=stop)
#     793         )
#     794     except BaseException as e:
#     795         for run_manager in run_managers:
#
# File C:\ProgramData\anaconda3\envs\torch_env\lib\site-packages\langchain_community\llms\ollama.py:437, in Ollama._generate(self, prompts, stop, images, run_manager, **kwargs)
#     435 generations = []
#     436 for prompt in prompts:
# --> 437     final_chunk = super()._stream_with_aggregation(
#     438         prompt,
#     439         stop=stop,
#     440         images=images,
#     441         run_manager=run_manager,
#     442         verbose=self.verbose,
#     443         **kwargs,
#     444     )
#     445     generations.append([final_chunk])
#     446 return LLMResult(generations=generations)
#
# File C:\ProgramData\anaconda3\envs\torch_env\lib\site-packages\langchain_community\llms\ollama.py:349, in _OllamaCommon._stream_with_aggregation(self, prompt, stop, run_manager, verbose, **kwargs)
#     340 def _stream_with_aggregation(
#     341     self,
#     342     prompt: str,
#    (...)
#     346     **kwargs: Any,
#     347 ) -> GenerationChunk:
#     348     final_chunk: Optional[GenerationChunk] = None
# --> 349     for stream_resp in self._create_generate_stream(prompt, stop, **kwargs):
#     350         if stream_resp:
#     351             chunk = _stream_response_to_generation_chunk(stream_resp)
#
# File C:\ProgramData\anaconda3\envs\torch_env\lib\site-packages\langchain_community\llms\ollama.py:194, in _OllamaCommon._create_generate_stream(self, prompt, stop, images, **kwargs)
#     186 def _create_generate_stream(
#     187     self,
#     188     prompt: str,
#    (...)
#     191     **kwargs: Any,
#     192 ) -> Iterator[str]:
#     193     payload = {"prompt": prompt, "images": images}
# --> 194     yield from self._create_stream(
#     195         payload=payload,
#     196         stop=stop,
#     197         api_url=f"{self.base_url}/api/generate",
#     198         **kwargs,
#     199     )
#
# File C:\ProgramData\anaconda3\envs\torch_env\lib\site-packages\requests\models.py:869, in Response.iter_lines(self, chunk_size, decode_unicode, delimiter)
#     860 """Iterates over the response data, one line at a time.  When
#     861 stream=True is set on the request, this avoids reading the
#     862 content at once into memory for large responses.
#     863
#     864 .. note:: This method is not reentrant safe.
#     865 """
#     867 pending = None
# --> 869 for chunk in self.iter_content(
#     870     chunk_size=chunk_size, decode_unicode=decode_unicode
#     871 ):
#     872     if pending is not None:
#     873         chunk = pending + chunk
#
# File C:\ProgramData\anaconda3\envs\torch_env\lib\site-packages\requests\utils.py:572, in stream_decode_response_unicode(iterator, r)
#     569     return
#     571 decoder = codecs.getincrementaldecoder(r.encoding)(errors="replace")
# --> 572 for chunk in iterator:
#     573     rv = decoder.decode(chunk)
#     574     if rv:
#
# File C:\ProgramData\anaconda3\envs\torch_env\lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File C:\ProgramData\anaconda3\envs\torch_env\lib\site-packages\urllib3\response.py:624, in HTTPResponse.stream(self, amt, decode_content)
#     608 """
#     609 A generator wrapper for the read() method. A call will block until
#     610 ``amt`` bytes have been read from the connection or until the
#    (...)
#     621     'content-encoding' header.
#     622 """
#     623 if self.chunked and self.supports_chunked_reads():
# --> 624     for line in self.read_chunked(amt, decode_content=decode_content):
#     625         yield line
#     626 else:
#
# File C:\ProgramData\anaconda3\envs\torch_env\lib\site-packages\urllib3\response.py:828, in HTTPResponse.read_chunked(self, amt, decode_content)
#     825     return
#     827 while True:
# --> 828     self._update_chunk_length()
#     829     if self.chunk_left == 0:
#     830         break
#
# File C:\ProgramData\anaconda3\envs\torch_env\lib\site-packages\urllib3\response.py:758, in HTTPResponse._update_chunk_length(self)
#     756 if self.chunk_left is not None:
#     757     return
# --> 758 line = self._fp.fp.readline()
#     759 line = line.split(b";", 1)[0]
#     760 try:
#
# File C:\ProgramData\anaconda3\envs\torch_env\lib\socket.py:716, in SocketIO.readinto(self, b)
#     714 while True:
#     715     try:
# --> 716         return self._sock.recv_into(b)
#     717     except timeout:
#     718         self._timeout_occurred = True
#
# KeyboardInterrupt:
